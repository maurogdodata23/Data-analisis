# %% [markdown]
# # Ejercicios de pandas
# Notebook con ejemplos prácticos para cada punto.

# %% [markdown]
# ## 1. Introducción a pandas

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ## 2. Series y DataFrames

# %%
s = pd.Series([10, 20, 30, 10], index=['a','b','c', 'd'])

#print(s.head(1))

#print(s.tail(1))
#print(s.shape)
#print(s.index)
#print(s.info)
#print(s.describe(percentiles=[0.10, 0.60, 0.90]))
print(s)
#print(s.quantile(0.90))
# Out:
# a    10
# b    20
# c    30
# d    10
# dtype: int64

# %%
df = pd.DataFrame({'pais':['MX','AR','MX'], 'ventas':[100,200,150]})

print(df.head(1))
print(df.tail(1))
print(df.shape)
print(df.index)
print(df.info)
print(df.describe())
print(df.dtypes)
# Out:
#   pais  ventas
# 0   MX     100
#   pais  ventas
# 2   MX     150
# (3, 2)
# RangeIndex(start=0, stop=3, step=1)
# <bound method DataFrame.info of   pais  ventas
# 0   MX     100
# 1   AR     200
# 2   MX     150>
#        ventas
# count     3.0
# mean    150.0
# std      50.0
# min     100.0
# 25%     125.0
# 50%     150.0
# 75%     175.0
# max     200.0
# pais      object
# ventas     int64
# dtype: object

# %% [markdown]
# ## 3. Importación y limpieza

# %%
url="https://github.com/Twoeme/Prueba2/raw/refs/heads/main/Pandas_Class/layoffs.csv"
df = pd.read_csv(url)
#df = pd.read_excel(url)#sep=";"
print(df)
# Out:
#                          company        location  total_laid_off        date  \
# 0                         Sonder     SF Bay Area             NaN  11/10/2025
# 1                        Axonius   New York City           100.0   11/6/2025
# 2                        MyBambu         Memphis           141.0   11/5/2025
# 3     Hewlett Packard Enterprise     SF Bay Area            52.0   11/5/2025
# 4                         Indeed          Austin             NaN   11/5/2025
# ...                          ...             ...             ...         ...
# 4197                     Service     Los Angeles             NaN   3/16/2020
# 4198                HopSkipDrive     Los Angeles             8.0   3/13/2020
# 4199                 Panda Squad     SF Bay Area             6.0   3/13/2020
# 4200               Tamara Mellon     Los Angeles            20.0   3/12/2020
# 4201                    EasyPost  Salt Lake City            75.0   3/11/2020
#
#       percentage_laid_off        industry  \
# 0                    1.00          Travel
# 1                    0.11        Security
# 2                    1.00         Finance
# 3                     NaN        Hardware
# 4                     NaN              HR
# ...                   ...             ...
# 4197                 1.00          Travel
# 4198                 0.10  Transportation
# 4199                 0.75        Consumer
# 4200                 0.40          Retail
# 4201                  NaN       Logistics
#
#                                                  source     stage  \
# 0     https://skift.com/2025/11/10/sonder-shuts-down...  Post-IPO
# 1     https://www.calcalistech.com/ctechnews/article...  Series E
# 2     https://cbs12.com/news/local/new-west-palm-bea...   Unknown
# 3     https://www.sfchronicle.com/tech/article/layof...  Post-IPO
# 4     https://www.businessinsider.com/indeed-layoffs...  Acquired
# ...                                                 ...       ...
# 4197  https://techcrunch.com/2020/03/16/travel-savin...      Seed
# 4198  https://layoffs.fyi/2020/04/02/hopskipdrive-la...   Unknown
# 4199  https://twitter.com/danielsinger/status/123854...      Seed
# 4200            https://layoffs.fyi/list/tamara-mellon/  Series C
# 4201  https://www.bizjournals.com/louisville/news/20...  Series A
#
#       funds_raised        country  date_added
# 0            839.0  United States  11/10/2025
# 1            865.0  United States   11/7/2025
# 2             15.0  United States   11/7/2025
# 3           1400.0  United States   11/7/2025
# 4              5.0  United States   11/8/2025
# ...            ...            ...         ...
# 4197           5.1  United States   8/31/2020
# 4198          45.0  United States    4/3/2020
# 4199           1.0  United States   4/17/2020
# 4200          90.0  United States   3/31/2020
# 4201          12.0  United States   3/31/2020
#
# [4202 rows x 11 columns]

# %% [markdown]
# #Limpieza de datos
# •	Valores faltantes
#
# •	Tipos incorrectos
#
# •	Errores de formato
#
# •	Nombres de columnas inconsistentes

# %%
print(df['country'].nunique())

#print(len(df['country'].unique()))
#print(df['country'].isna().sum())
# Out:
# 66

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df.isna().sum()
# Out:
# company                   0
# location                  1
# total_laid_off         1459
# date                      0
# percentage_laid_off    1543
# industry                  2
# source                    3
# stage                     5
# funds_raised            475
# country                   2
# date_added                0
# dtype: int64

# %%
df['date']= pd.to_datetime(df['date'])
df['date'].dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              4202 non-null   object
#  1   location             4201 non-null   object
#  2   total_laid_off       2743 non-null   float64
#  3   date                 4202 non-null   datetime64[ns]
#  4   percentage_laid_off  2659 non-null   float64
#  5   industry             4200 non-null   object
#  6   source               4199 non-null   object
#  7   stage                4197 non-null   object
#  8   funds_raised         3727 non-null   float64
#  9   country              4200 non-null   object
#  10  date_added           4202 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 361.2+ KB

# %%
#df.info()

companias = df['company'].unique()
locations = df['location'].unique()
industries = df['industry'].unique()   
countries = df['country'].unique()
date= df['date'].unique()
#total_laidoff = df['total_laid_off'].sum()
#print(f'Total de despidos: {total_laidoff}')
#print(len(companias))

print(df['company'].nunique())
print(df['company'].unique())
print(df['country'].nunique())
# Out:
# 2836
# ['Sonder' 'Axonius' 'MyBambu' ... 'Help.com' 'Panda Squad' 'Tamara Mellon']
# 66

# %%
df['country'].isna().sum()
# Out:
# np.int64(2)

# %%
print(len (locations))
# Out:
# 267

# %%
df['industry'].isna().sum()
# Out:
# np.int64(2)

# %%
df.dropna(how='all')
#df.dropna(how='any')
media = df['total_laid_off'].mean()

df['total_laid_off'] = df['total_laid_off'].fillna(media)
df['industry'] = df['industry'].fillna("Unknown")
df['country'] = df['industry'].fillna("Unknown")     

#df.fillna(method="bfill", "ffill")
#Rellenar con un número
#Rellenar con la media de la columna
#Rellenar con el valor anterior (method="ffill")
#Rellenar con el siguiente (method="bfill")
df['total_laid_off'].isna().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              4202 non-null   object
#  1   location             4201 non-null   object
#  2   total_laid_off       4202 non-null   float64
#  3   date                 4202 non-null   datetime64[ns]
#  4   percentage_laid_off  2659 non-null   float64
#  5   industry             4202 non-null   object
#  6   source               4199 non-null   object
#  7   stage                4197 non-null   object
#  8   funds_raised         3727 non-null   float64
#  9   country              4202 non-null   object
#  10  date_added           4202 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 361.2+ KB

# %% [markdown]
# <h1>Reto 4</h1>

# %%
df['stage'] = df['stage'].fillna("Unknown")
df['source'] = df['source'].fillna("Unknown")

# %%
media2 = df['percentage_laid_off'].mean()
df['percentage_laid_off'] = df['percentage_laid_off'].fillna(media2)
df['funds_raised'] = df['funds_raised'].fillna(0)
df['location'] = df['location'].fillna("Unknown")  

df.isna().sum()
# Out:
# company                0
# location               0
# total_laid_off         0
# date                   0
# percentage_laid_off    0
# industry               0
# source                 0
# stage                  0
# funds_raised           0
# country                0
# date_added             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
df.drop_duplicates()
#subset=["col1","col2"] → considerar duplicadas solo esas columnas
#keep="first" o keep="last"
# Out:
#                          company        location  total_laid_off       date  \
# 0                         Sonder     SF Bay Area      287.806781 2025-11-10
# 1                        Axonius   New York City      100.000000 2025-11-06
# 2                        MyBambu         Memphis      141.000000 2025-11-05
# 3     Hewlett Packard Enterprise     SF Bay Area       52.000000 2025-11-05
# 4                         Indeed          Austin      287.806781 2025-11-05
# ...                          ...             ...             ...        ...
# 4197                     Service     Los Angeles      287.806781 2020-03-16
# 4198                HopSkipDrive     Los Angeles        8.000000 2020-03-13
# 4199                 Panda Squad     SF Bay Area        6.000000 2020-03-13
# 4200               Tamara Mellon     Los Angeles       20.000000 2020-03-12
# 4201                    EasyPost  Salt Lake City       75.000000 2020-03-11
#
#       percentage_laid_off        industry  \
# 0                1.000000          Travel
# 1                0.110000        Security
# 2                1.000000         Finance
# 3                0.294064        Hardware
# 4                0.294064              HR
# ...                   ...             ...
# 4197             1.000000          Travel
# 4198             0.100000  Transportation
# 4199             0.750000        Consumer
# 4200             0.400000          Retail
# 4201             0.294064       Logistics
#
#                                                  source     stage  \
# 0     https://skift.com/2025/11/10/sonder-shuts-down...  Post-IPO
# 1     https://www.calcalistech.com/ctechnews/article...  Series E
# 2     https://cbs12.com/news/local/new-west-palm-bea...   Unknown
# 3     https://www.sfchronicle.com/tech/article/layof...  Post-IPO
# 4     https://www.businessinsider.com/indeed-layoffs...  Acquired
# ...                                                 ...       ...
# 4197  https://techcrunch.com/2020/03/16/travel-savin...      Seed
# 4198  https://layoffs.fyi/2020/04/02/hopskipdrive-la...   Unknown
# 4199  https://twitter.com/danielsinger/status/123854...      Seed
# 4200            https://layoffs.fyi/list/tamara-mellon/  Series C
# 4201  https://www.bizjournals.com/louisville/news/20...  Series A
#
#       funds_raised         country  date_added
# 0            839.0          Travel  11/10/2025
# 1            865.0        Security   11/7/2025
# 2             15.0         Finance   11/7/2025
# 3           1400.0        Hardware   11/7/2025
# 4              5.0              HR   11/8/2025
# ...            ...             ...         ...
# 4197           5.1          Travel   8/31/2020
# 4198          45.0  Transportation    4/3/2020
# 4199           1.0        Consumer   4/17/2020
# 4200          90.0          Retail   3/31/2020
# 4201          12.0       Logistics   3/31/2020
#
# [4202 rows x 11 columns]

# %%
variable = 2
variable += 5
print(variable)
# Out:
# 7

# %%
df= df.rename(columns={"company":"compania","location":"ubicacion","date":"fecha","percentage_laid_off":"porcentaje_despidos"})
df.rename(columns={"industry":"industria","source":"fuente","stage":"etapa","funds_raised":"fondos_recaudados","country":"sector_economico","date_added":"fecha_agregado"}, inplace=True)
df=df.rename(columns={"total_laid_off":"total_despidos"})
df.info()
 #5   industry             4202 non-null   object        
 #6   source               4199 non-null   object        
 #7   stage                4197 non-null   object        
 #8   funds_raised         3727 non-null   float64       
 #9   country              4202 non-null   object        
 #10  date_added
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   compania             4202 non-null   object
#  1   ubicacion            4202 non-null   object
#  2   total_despidos       4202 non-null   float64
#  3   fecha                4202 non-null   datetime64[ns]
#  4   porcentaje_despidos  4202 non-null   float64
#  5   industria            4202 non-null   object
#  6   fuente               4202 non-null   object
#  7   etapa                4202 non-null   object
#  8   fondos_recaudados    4202 non-null   float64
#  9   sector_economico     4202 non-null   object
#  10  fecha_agregado       4202 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 361.2+ KB

# %%
df['etapa'].unique()
# Out:
# array(['Post-IPO', 'Series E', 'Unknown', 'Acquired', 'Series F',
#        'Series D', 'Series C', 'Series B', 'Series A', 'Private Equity',
#        'Seed', 'Subsidiary', 'Series G', 'Series J', 'Series I',
#        'Series H'], dtype=object)

# %%
#df=df.rename(columns={"pais":"sector_economico"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   compania             4202 non-null   object
#  1   ubicacion            4202 non-null   object
#  2   total_despidos       4202 non-null   float64
#  3   fecha                4202 non-null   datetime64[ns]
#  4   porcentaje_despidos  4202 non-null   float64
#  5   industria            4202 non-null   object
#  6   fuente               4202 non-null   object
#  7   etapa                4202 non-null   object
#  8   fondos_recaudados    4202 non-null   float64
#  9   sector_economico     4202 non-null   object
#  10  fecha_agregado       4202 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 361.2+ KB

# %%
df.columns = df.columns.str.lower()

# %%
df['ubicacion'] = df['ubicacion'].str.replace(" ", "_")

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
#df["col"] = df["col"].astype(int)
#df["fecha"] = pd.to_datetime(df["fecha"])

# %%
#df["etapa"] = df["etapa"].astype("category") #No es buena practica
#df['etapa'].dtypes

# %% [markdown]
# # Flujo típico de limpieza
# 1.	Cargar archivo (CSV, Excel, JSON).
#
# 2.	Explorar estructura con .head(), .info(), .describe().
#
# 3.	Renombrar columnas.
#
# 4.	Tratar valores nulos.
#
# 5.	Eliminar duplicados.
#
# 6.	Arreglar tipos de datos.
#
# 7.	Verificar resultados.

# %% [markdown]
# ## 4. Selección y filtrado

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   compania             4202 non-null   object
#  1   ubicacion            4202 non-null   object
#  2   total_despidos       4202 non-null   float64
#  3   fecha                4202 non-null   datetime64[ns]
#  4   porcentaje_despidos  4202 non-null   float64
#  5   industria            4202 non-null   object
#  6   fuente               4202 non-null   object
#  7   etapa                4202 non-null   object
#  8   fondos_recaudados    4202 non-null   float64
#  9   sector_economico     4202 non-null   object
#  10  fecha_agregado       4202 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 361.2+ KB

# %%
companias_NY = df.loc[df['ubicacion'] == 'New_York_City',['compania', 'etapa', 'sector_economico','fondos_recaudados']]
companias_NY.reset_index(drop=True, inplace=True)
#print(companias_NY.sort_values(by='fondos_recaudados', ascending=False).head(10))
#print(companias_NY.head(10) )
companias_NY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   compania           422 non-null    object
#  1   etapa              422 non-null    object
#  2   sector_economico   422 non-null    object
#  3   fondos_recaudados  422 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 13.3+ KB

# %%
revisar_pais = df.loc[df['ubicacion'] == 'Unknown',['compania', 'etapa', 'sector_economico','fondos_recaudados']]
print(revisar_pais)
# Out:
#           compania     etapa sector_economico  fondos_recaudados
# 1092  Product Hunt  Acquired         Consumer                0.0

# %%
df[['compania', 'ubicacion']]
#df.loc[:, ["compania","pais"]]
# Out:
#                         compania       ubicacion
# 0                         Sonder     SF_Bay_Area
# 1                        Axonius   New_York_City
# 2                        MyBambu         Memphis
# 3     Hewlett Packard Enterprise     SF_Bay_Area
# 4                         Indeed          Austin
# ...                          ...             ...
# 4197                     Service     Los_Angeles
# 4198                HopSkipDrive     Los_Angeles
# 4199                 Panda Squad     SF_Bay_Area
# 4200               Tamara Mellon     Los_Angeles
# 4201                    EasyPost  Salt_Lake_City
#
# [4202 rows x 2 columns]

# %%
df.iloc[[2,4], 2:5]
#df.iloc[[12, 13, 17], 0:3]
# Out:
#    total_despidos      fecha  porcentaje_despidos
# 2      141.000000 2025-11-05             1.000000
# 4      287.806781 2025-11-05             0.294064

# %%
#df[df['fecha'] > '2024-01-01']
df[(df['fecha'] > '2024-01-01') & (df['ubicacion'] == 'SF_Bay_Area')]
#df[(df['fecha'] > '2024-01-01') | (df['ubicacion'] == 'SF_Bay_Area')]
# Out:
#                        compania    ubicacion  total_despidos      fecha  \
# 0                        Sonder  SF_Bay_Area      287.806781 2025-11-10
# 3    Hewlett Packard Enterprise  SF_Bay_Area       52.000000 2025-11-05
# 9                         Chegg  SF_Bay_Area      388.000000 2025-10-27
# 13             Applied Material  SF_Bay_Area     1400.000000 2025-10-23
# 15                     Altruist  SF_Bay_Area       50.000000 2025-10-23
# ..                          ...          ...             ...        ...
# 880          Treasure Financial  SF_Bay_Area       14.000000 2024-01-09
# 881                      Humane  SF_Bay_Area       10.000000 2024-01-09
# 885                       Unity  SF_Bay_Area     1800.000000 2024-01-08
# 895                     LiveVox  SF_Bay_Area      287.806781 2024-01-07
# 898                       Lever  SF_Bay_Area      287.806781 2024-01-05
#
#      porcentaje_despidos      industria  \
# 0               1.000000         Travel
# 3               0.294064       Hardware
# 9               0.450000      Education
# 13              0.040000  Manufacturing
# 15              0.150000        Finance
# ..                   ...            ...
# 880             0.600000        Finance
# 881             0.040000       Hardware
# 885             0.250000          Other
# 895             0.294064        Support
# 898             0.294064     Recruiting
#
#                                                 fuente     etapa  \
# 0    https://skift.com/2025/11/10/sonder-shuts-down...  Post-IPO
# 3    https://www.sfchronicle.com/tech/article/layof...  Post-IPO
# 9    https://www.reuters.com/sustainability/boards-...  Post-IPO
# 13   https://www.bloomberg.com/news/articles/2025-1...  Post-IPO
# 15   https://www.investmentnews.com/ria-news/altrui...  Series E
# ..                                                 ...       ...
# 880  https://techcrunch.com/2024/01/09/treasure-fin...  Series A
# 881  https://www.theverge.com/2024/1/9/24032274/hum...  Series C
# 885  https://www.reuters.com/technology/unity-softw...  Post-IPO
# 895  https://www.channelfutures.com/unified-communi...  Acquired
# 898  https://sfstandard.com/2024/01/05/lever-san-fr...  Acquired
#
#      fondos_recaudados sector_economico fecha_agregado
# 0                839.0           Travel     11/10/2025
# 3               1400.0         Hardware      11/7/2025
# 9                227.0        Education     10/28/2025
# 13              2100.0    Manufacturing     10/25/2025
# 15               449.0          Finance     10/25/2025
# ..                 ...              ...            ...
# 880               14.0          Finance      1/30/2024
# 881              230.0         Hardware      1/10/2024
# 885             1300.0            Other       1/8/2024
# 895               12.0          Support      1/20/2024
# 898              123.0       Recruiting       1/7/2024
#
# [226 rows x 11 columns]

# %%
df[df['ubicacion'] != 'New_York_City']
# Out:
#                         compania       ubicacion  total_despidos      fecha  \
# 0                         Sonder     SF_Bay_Area      287.806781 2025-11-10
# 2                        MyBambu         Memphis      141.000000 2025-11-05
# 3     Hewlett Packard Enterprise     SF_Bay_Area       52.000000 2025-11-05
# 4                         Indeed          Austin      287.806781 2025-11-05
# 5                    TripAdvisor          Boston      287.806781 2025-11-05
# ...                          ...             ...             ...        ...
# 4197                     Service     Los_Angeles      287.806781 2020-03-16
# 4198                HopSkipDrive     Los_Angeles        8.000000 2020-03-13
# 4199                 Panda Squad     SF_Bay_Area        6.000000 2020-03-13
# 4200               Tamara Mellon     Los_Angeles       20.000000 2020-03-12
# 4201                    EasyPost  Salt_Lake_City       75.000000 2020-03-11
#
#       porcentaje_despidos       industria  \
# 0                1.000000          Travel
# 2                1.000000         Finance
# 3                0.294064        Hardware
# 4                0.294064              HR
# 5                0.200000          Travel
# ...                   ...             ...
# 4197             1.000000          Travel
# 4198             0.100000  Transportation
# 4199             0.750000        Consumer
# 4200             0.400000          Retail
# 4201             0.294064       Logistics
#
#                                                  fuente     etapa  \
# 0     https://skift.com/2025/11/10/sonder-shuts-down...  Post-IPO
# 2     https://cbs12.com/news/local/new-west-palm-bea...   Unknown
# 3     https://www.sfchronicle.com/tech/article/layof...  Post-IPO
# 4     https://www.businessinsider.com/indeed-layoffs...  Acquired
# 5     https://skift.com/2025/11/05/layoffs-hit-20-of...  Post-IPO
# ...                                                 ...       ...
# 4197  https://techcrunch.com/2020/03/16/travel-savin...      Seed
# 4198  https://layoffs.fyi/2020/04/02/hopskipdrive-la...   Unknown
# 4199  https://twitter.com/danielsinger/status/123854...      Seed
# 4200            https://layoffs.fyi/list/tamara-mellon/  Series C
# 4201  https://www.bizjournals.com/louisville/news/20...  Series A
#
#       fondos_recaudados sector_economico fecha_agregado
# 0                 839.0           Travel     11/10/2025
# 2                  15.0          Finance      11/7/2025
# 3                1400.0         Hardware      11/7/2025
# 4                   5.0               HR      11/8/2025
# 5                   3.0           Travel      11/7/2025
# ...                 ...              ...            ...
# 4197                5.1           Travel      8/31/2020
# 4198               45.0   Transportation       4/3/2020
# 4199                1.0         Consumer      4/17/2020
# 4200               90.0           Retail      3/31/2020
# 4201               12.0        Logistics      3/31/2020
#
# [3780 rows x 11 columns]

# %%
df['sector_economico'].nunique()
# Out:
# 31

# %%
ubicacion_fecha = df.query("ubicacion == 'Norwalk' and fecha > '2024-01-01'")
ciudad = 'Boston'
sector_economico= df.query("sector_economico == 'Travel' or ubicacion == @ciudad")
revision=df.query("sector_economico.isnull()")
print(revision)
# Out:
# Empty DataFrame
# Columns: [compania, ubicacion, total_despidos, fecha, porcentaje_despidos, industria, fuente, etapa, fondos_recaudados, sector_economico, fecha_agregado]
# Index: []

# %% [markdown]
# ## 5. Transformación de datos

# %%
df['despidos_por_fondo'] = df['total_despidos'] / (df['fondos_recaudados'] + 1)  # Añadimos 1 para evitar división por cero
print(df['despidos_por_fondo'])
df.drop(columns=['despidos_por_fondo'], inplace=True)
# Out:
# 0        0.342627
# 1        0.115473
# 2        8.812500
# 3        0.037116
# 4       47.967797
#           ...
# 4197    47.181439
# 4198     0.173913
# 4199     3.000000
# 4200     0.219780
# 4201     5.769231
# Name: despidos_por_fondo, Length: 4202, dtype: float64

# %%
df_nde = df['total_despidos'].astype(int)
print(df_nde)
# Out:
# 0       287
# 1       100
# 2       141
# 3        52
# 4       287
#        ...
# 4197    287
# 4198      8
# 4199      6
# 4200     20
# 4201     75
# Name: total_despidos, Length: 4202, dtype: int64

# %%
df['etapa'].nunique()
print(df['etapa'].unique())
# Out:
# ['Post-IPO' 'Series E' 'Unknown' 'Acquired' 'Series F' 'Series D'
#  'Series C' 'Series B' 'Series A' 'Private Equity' 'Seed' 'Subsidiary'
#  'Series G' 'Series J' 'Series I' 'Series H']

# %%
df['etapa'].nunique()
# Out:
# 16

# %%
df.apply(lambda x: x.astype(str).str.upper())
#df['sexo']=df['sexo'].map({"M":"Masculino", "F":"Femenino"})
#print(df['etapa'].head(30))
# Out:
#                         compania       ubicacion     total_despidos  \
# 0                         SONDER     SF_BAY_AREA  287.8067808968283
# 1                        AXONIUS   NEW_YORK_CITY              100.0
# 2                        MYBAMBU         MEMPHIS              141.0
# 3     HEWLETT PACKARD ENTERPRISE     SF_BAY_AREA               52.0
# 4                         INDEED          AUSTIN  287.8067808968283
# ...                          ...             ...                ...
# 4197                     SERVICE     LOS_ANGELES  287.8067808968283
# 4198                HOPSKIPDRIVE     LOS_ANGELES                8.0
# 4199                 PANDA SQUAD     SF_BAY_AREA                6.0
# 4200               TAMARA MELLON     LOS_ANGELES               20.0
# 4201                    EASYPOST  SALT_LAKE_CITY               75.0
#
#            fecha porcentaje_despidos       industria  \
# 0     2025-11-10                 1.0          TRAVEL
# 1     2025-11-06                0.11        SECURITY
# 2     2025-11-05                 1.0         FINANCE
# 3     2025-11-05  0.2940644979315532        HARDWARE
# 4     2025-11-05  0.2940644979315532              HR
# ...          ...                 ...             ...
# 4197  2020-03-16                 1.0          TRAVEL
# 4198  2020-03-13                 0.1  TRANSPORTATION
# 4199  2020-03-13                0.75        CONSUMER
# 4200  2020-03-12                 0.4          RETAIL
# 4201  2020-03-11  0.2940644979315532       LOGISTICS
#
#                                                  fuente     etapa  \
# 0     HTTPS://SKIFT.COM/2025/11/10/SONDER-SHUTS-DOWN...  POST-IPO
# 1     HTTPS://WWW.CALCALISTECH.COM/CTECHNEWS/ARTICLE...  SERIES E
# 2     HTTPS://CBS12.COM/NEWS/LOCAL/NEW-WEST-PALM-BEA...   UNKNOWN
# 3     HTTPS://WWW.SFCHRONICLE.COM/TECH/ARTICLE/LAYOF...  POST-IPO
# 4     HTTPS://WWW.BUSINESSINSIDER.COM/INDEED-LAYOFFS...  ACQUIRED
# ...                                                 ...       ...
# 4197  HTTPS://TECHCRUNCH.COM/2020/03/16/TRAVEL-SAVIN...      SEED
# 4198  HTTPS://LAYOFFS.FYI/2020/04/02/HOPSKIPDRIVE-LA...   UNKNOWN
# 4199  HTTPS://TWITTER.COM/DANIELSINGER/STATUS/123854...      SEED
# 4200            HTTPS://LAYOFFS.FYI/LIST/TAMARA-MELLON/  SERIES C
# 4201  HTTPS://WWW.BIZJOURNALS.COM/LOUISVILLE/NEWS/20...  SERIES A
#
#      fondos_recaudados sector_economico fecha_agregado
# 0                839.0           TRAVEL     11/10/2025
# 1                865.0         SECURITY      11/7/2025
# 2                 15.0          FINANCE      11/7/2025
# 3               1400.0         HARDWARE      11/7/2025
# 4                  5.0               HR      11/8/2025
# ...                ...              ...            ...
# 4197               5.1           TRAVEL      8/31/2020
# 4198              45.0   TRANSPORTATION       4/3/2020
# 4199               1.0         CONSUMER      4/17/2020
# 4200              90.0           RETAIL      3/31/2020
# 4201              12.0        LOGISTICS      3/31/2020
#
# [4202 rows x 11 columns]

# %% [markdown]
# ## 6. Agrupaciones y análisis

# %%
df.drop(columns=['fecha'], inplace=True)

# %%
df.info()
df['etapa']=df['etapa'].astype(object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   compania             4202 non-null   object
#  1   ubicacion            4202 non-null   object
#  2   total_despidos       4202 non-null   float64
#  3   porcentaje_despidos  4202 non-null   float64
#  4   industria            4202 non-null   object
#  5   fuente               4202 non-null   object
#  6   etapa                4202 non-null   object
#  7   fondos_recaudados    4202 non-null   float64
#  8   sector_economico     4202 non-null   object
#  9   fecha_agregado       4202 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 328.4+ KB

# %%
companias_despidos = pd.DataFrame({
    'compania':df['compania'],
    'total_despidos':df['total_despidos'],
    'porcentaje_despidos':df['porcentaje_despidos'],
    'etapa':df['etapa']
    })

# %%
companias_despidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   compania             4202 non-null   object
#  1   total_despidos       4202 non-null   float64
#  2   porcentaje_despidos  4202 non-null   float64
#  3   etapa                4202 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 131.4+ KB

# %%
companias_NY_etapas = companias_NY.groupby('etapa').count()
print(companias_NY_etapas)
companias_despidos['total_despidos']=companias_despidos['total_despidos'].astype(int)
companias_despidos['porcentaje_despidos']=companias_despidos['porcentaje_despidos'].astype(int)
#companias_despidos.groupby('compania').mean()
# Out:
#                 compania  sector_economico  fondos_recaudados
# etapa
# Acquired              38                38                 38
# Post-IPO              89                89                 89
# Private Equity         5                 5                  5
# Seed                   9                 9                  9
# Series A              27                27                 27
# Series B              55                55                 55
# Series C              35                35                 35
# Series D              49                49                 49
# Series E              28                28                 28
# Series F              18                18                 18
# Series G               2                 2                  2
# Series H               1                 1                  1
# Subsidiary             2                 2                  2
# Unknown               64                64                 64

# %%
total_despidos_tabla=df.groupby(['etapa','ubicacion']).agg({'total_despidos':['sum','mean', 'max'], 'porcentaje_despidos':['sum','mean','count', 'max']})
#total_despidos_tabla.to_excel('total_despidos_por_etapa_y_ubicacion.xlsx', index=True, sheet_name='Resumen_despidos')

# %%
companias_NY=companias_NY.drop_duplicates()
companias_NY.to_excel('companias_NY.xlsx', index=True, sheet_name='Companias_NY')

# %%
df.groupby(['etapa','ubicacion'])['total_despidos'].sum()
# Out:
# etapa     ubicacion
# Acquired  Albany                  371.000000
#           Amsterdam,_Non-U.S.    7835.000000
#           Ann_Arbor               200.000000
#           Atlanta                 387.806781
#           Austin                 5075.613562
#                                     ...
# Unknown   Vilnius,_Non-U.S.       287.806781
#           Washington_D.C.         494.806781
#           Xi'an,_Non-U.S.         287.806781
#           Yangon,_Non-U.S.        200.000000
#           Zurich,_Non-U.S.        287.806781
# Name: total_despidos, Length: 813, dtype: float64

# %% [markdown]
# ## 7. Unión y combinación

# %%
pd.pivot_table(df, index='etapa', columns='ubicacion', values='total_despidos', aggfunc='sum', fill_value=0)
# Out:
# ubicacion       Abuja,_Non-U.S.  Accra,_Non-U.S.  Ahmedabad,_Non-U.S.  \
# etapa
# Acquired               0.000000         0.000000                  0.0
# Post-IPO               0.000000         0.000000                  0.0
# Private Equity         0.000000         0.000000                  0.0
# Seed                 287.806781         0.000000                  0.0
# Series A               0.000000         0.000000                  0.0
# Series B               0.000000         0.000000                  0.0
# Series C               0.000000         0.000000                  0.0
# Series D               0.000000       150.000000                  0.0
# Series E               0.000000         0.000000                  0.0
# Series F               0.000000         0.000000                  0.0
# Series G               0.000000         0.000000                  0.0
# Series H               0.000000         0.000000                  0.0
# Series I               0.000000         0.000000                  0.0
# Series J               0.000000         0.000000                  0.0
# Subsidiary             0.000000         0.000000                  0.0
# Unknown                0.000000       287.806781                500.0
#
# ubicacion          Alamosa  Albany  Amsterdam,_Non-U.S.   Ann_Arbor  \
# etapa
# Acquired          0.000000   371.0          7835.000000  200.000000
# Post-IPO          0.000000     0.0         11702.806781    0.000000
# Private Equity  287.806781     0.0             0.000000    0.000000
# Seed              0.000000     0.0             0.000000    0.000000
# Series A          0.000000     0.0            35.000000    0.000000
# Series B          0.000000     0.0             0.000000   40.000000
# Series C          0.000000     0.0          1073.420343  100.000000
# Series D          0.000000     0.0             0.000000  287.806781
# Series E          0.000000     0.0             0.000000    0.000000
# Series F          0.000000     0.0             0.000000    0.000000
# Series G          0.000000     0.0             0.000000    0.000000
# Series H          0.000000     0.0             0.000000    0.000000
# Series I          0.000000     0.0             0.000000    0.000000
# Series J          0.000000     0.0             0.000000    0.000000
# Subsidiary        0.000000     0.0             0.000000    0.000000
# Unknown           0.000000     0.0          1151.227124    0.000000
#
# ubicacion       Athens,_Non-U.S.      Atlanta  Auckland  ...  \
# etapa                                                    ...
# Acquired                0.000000   387.806781       0.0  ...
# Post-IPO                0.000000   878.806781      45.0  ...
# Private Equity          0.000000     0.000000       0.0  ...
# Seed                    0.000000     0.000000       0.0  ...
# Series A                0.000000    90.000000       0.0  ...
# Series B              287.806781   578.806781       0.0  ...
# Series C                0.000000  1525.613562       0.0  ...
# Series D                0.000000   218.000000       0.0  ...
# Series E                0.000000   287.806781       0.0  ...
# Series F                0.000000     0.000000       0.0  ...
# Series G                0.000000     0.000000       0.0  ...
# Series H                0.000000     0.000000       0.0  ...
# Series I                0.000000     0.000000       0.0  ...
# Series J                0.000000     0.000000       0.0  ...
# Subsidiary              0.000000     0.000000       0.0  ...
# Unknown                 0.000000  1882.840685       0.0  ...
#
# ubicacion       Waterloo,_Non-U.S.  Wellington,_Non-U.S.  Wilmington  \
# etapa
# Acquired                287.806781              0.000000    0.000000
# Post-IPO               3375.613562            800.000000  387.806781
# Private Equity            0.000000              0.000000    0.000000
# Seed                     22.000000              0.000000    0.000000
# Series A                  0.000000              0.000000  287.806781
# Series B                 13.000000              0.000000    0.000000
# Series C                  0.000000            287.806781    0.000000
# Series D                377.806781              0.000000    0.000000
# Series E                  0.000000              0.000000    0.000000
# Series F                  0.000000              0.000000    0.000000
# Series G                  0.000000              0.000000    0.000000
# Series H                  0.000000              0.000000    0.000000
# Series I                  0.000000              0.000000    0.000000
# Series J                  0.000000              0.000000    0.000000
# Subsidiary                0.000000              0.000000    0.000000
# Unknown                   0.000000              0.000000    0.000000
#
# ubicacion       Winnipeg,_Non-U.S.  Wrocław,_Non-U.S.  Xi'an,_Non-U.S.  \
# etapa
# Acquired                    1150.0                0.0         0.000000
# Post-IPO                       0.0                0.0         0.000000
# Private Equity                 0.0                0.0         0.000000
# Seed                           0.0              120.0         0.000000
# Series A                       0.0                0.0         0.000000
# Series B                       0.0                0.0         0.000000
# Series C                       0.0                0.0         0.000000
# Series D                       0.0                0.0         0.000000
# Series E                       0.0                0.0         0.000000
# Series F                       0.0                0.0         0.000000
# Series G                       0.0                0.0         0.000000
# Series H                       0.0                0.0         0.000000
# Series I                       0.0                0.0         0.000000
# Series J                       0.0                0.0         0.000000
# Subsidiary                     0.0                0.0         0.000000
# Unknown                        0.0                0.0       287.806781
#
# ubicacion       Yangon,_Non-U.S.  Yavne,_Non-U.S.  Zug,_Non-U.S.  \
# etapa
# Acquired                     0.0            100.0       0.000000
# Post-IPO                     0.0              0.0       0.000000
# Private Equity               0.0              0.0       0.000000
# Seed                         0.0              0.0       0.000000
# Series A                     0.0              0.0       0.000000
# Series B                     0.0              0.0     575.613562
# Series C                     0.0              0.0       0.000000
# Series D                     0.0              0.0       0.000000
# Series E                     0.0              0.0       0.000000
# Series F                     0.0              0.0       0.000000
# Series G                     0.0              0.0       0.000000
# Series H                     0.0              0.0       0.000000
# Series I                     0.0              0.0       0.000000
# Series J                     0.0              0.0       0.000000
# Subsidiary                   0.0              0.0       0.000000
# Unknown                    200.0              0.0       0.000000
#
# ubicacion       Zurich,_Non-U.S.
# etapa
# Acquired                0.000000
# Post-IPO                0.000000
# Private Equity        393.806781
# Seed                    0.000000
# Series A                0.000000
# Series B               62.000000
# Series C                0.000000
# Series D                0.000000
# Series E                0.000000
# Series F                0.000000
# Series G                0.000000
# Series H                0.000000
# Series I                0.000000
# Series J                0.000000
# Subsidiary              0.000000
# Unknown               287.806781
#
# [16 rows x 267 columns]

# %%
Companias_SF = df.loc[df['ubicacion'] == 'SF_Bay_Area',['compania', 'etapa', 'sector_economico','fondos_recaudados']]
Companias_SF.drop_duplicates(inplace=True)
Companias_SF.to_excel('companias_SF.xlsx', index=False, sheet_name='Companias_SF')

# %%
comNY='https://github.com/Twoeme/Prueba2/raw/refs/heads/main/Pandas_Class/companias_NY.xlsx'
companias_NY = pd.read_excel(comNY, sheet_name='Companias_NY')
companias_NY.drop('Unnamed: 0', axis=1, inplace=True)

# %%
comSF='https://github.com/Twoeme/Prueba2/raw/refs/heads/main/Pandas_Class/companias_SF.xlsx'
companias_SF = pd.read_excel(comSF, sheet_name='Companias_SF')

# %%
dfNYSF = pd.merge(companias_NY, companias_SF, on='compania', how='outer', suffixes=('_NY', '_SF'))
print(dfNYSF)
# Out:
#               compania  etapa_NY sector_economico_NY  fondos_recaudados_NY  \
# 0      Included Health       NaN                 NaN                   NaN
# 1         10X Genomics       NaN                 NaN                   NaN
# 2              1stdibs  Series D              Retail                 253.0
# 3              23andMe       NaN                 NaN                   NaN
# 4               6sense       NaN                 NaN                   NaN
# ...                ...       ...                 ...                   ...
# 1042              dYdX       NaN                 NaN                   NaN
# 1043              eBay       NaN                 NaN                   NaN
# 1044           inDrive       NaN                 NaN                   NaN
# 1045             tZero  Acquired             Finance                 472.0
# 1046               xAI       NaN                 NaN                   NaN
#
#       etapa_SF sector_economico_SF  fondos_recaudados_SF
# 0     Series E          Healthcare                 272.0
# 1     Post-IPO          Healthcare                 242.0
# 2          NaN                 NaN                   NaN
# 3     Post-IPO          Healthcare                1100.0
# 4     Series E               Sales                 426.0
# ...        ...                 ...                   ...
# 1042  Series C              Crypto                  87.0
# 1043  Post-IPO              Retail                1200.0
# 1044   Unknown      Transportation                 387.0
# 1045       NaN                 NaN                   NaN
# 1046   Unknown                  AI               22700.0
#
# [1047 rows x 7 columns]

# %%
dfNYSF2 = pd.concat([companias_SF, companias_NY], axis=0, ignore_index=True)
with pd.ExcelWriter('companias_NY_SF_concatenadas.xlsx', engine='openpyxl') as writer:
    dfNYSF2.to_excel(writer, index=False, sheet_name='Companias_NY_SF')    
    dfNYSF.to_excel(writer, index=False, sheet_name='Companias_NY_SF_Merge')

print(dfNYSF2)
# Out:
#                         compania     etapa sector_economico  fondos_recaudados
# 0                         Sonder  Post-IPO           Travel              839.0
# 1     Hewlett Packard Enterprise  Post-IPO         Hardware             1400.0
# 2                          Chegg  Post-IPO        Education              227.0
# 3               Applied Material  Post-IPO    Manufacturing             2100.0
# 4                       Altruist  Series E          Finance              449.0
# ...                          ...       ...              ...                ...
# 1044                     Compass  Series G      Real Estate             1600.0
# 1045                     Convene  Series D      Real Estate              280.0
# 1046                 Eight Sleep  Series C           Retail               70.0
# 1047             Flywheel Sports  Acquired          Fitness              120.0
# 1048                       Popin   Unknown          Fitness               13.0
#
# [1049 rows x 4 columns]

# %%
df1 = pd.DataFrame({'companias':['Mattel','Servientrega','DollarCity'], 'Ventas':[10,20,40]})
df2 = pd.DataFrame({'companias':["Mattel","DollarCity"], 'Ventas':[100,300]})


df3 = pd.merge(df1, df2, on='companias', how='right')
#df3 = df3.fillna(100)
#df3['Ventas_y'][2] = 200
print(df3)
# Out:
#     companias  Ventas_x  Ventas_y
# 0      Mattel        10       100
# 1  DollarCity        40       300

# %%
df3 = df1+df2
print(df3)
# Out:
#                 companias  Ventas
# 0            MattelMattel   110.0
# 1  ServientregaDollarCity   320.0
# 2                     NaN     NaN

# %%
Q1= df['total_despidos'].quantile(0.25)
Q3= df['total_despidos'].quantile(0.75)
IQR= Q3 - Q1    
print(IQR)
limite_inferior= Q1 - 1.5 * IQR
limite_superior= Q3 + 1.5 * IQR
outliers = df[(df['total_despidos'] < limite_inferior) | (df['total_despidos'] > limite_superior)]
print(outliers)
# Out:
# 227.8067808968283
#                 compania        ubicacion  total_despidos  \
# 8                 Amazon          Seattle         14000.0
# 13      Applied Material      SF_Bay_Area          1400.0
# 53            Salesforce      SF_Bay_Area          4000.0
# 98                 Intel       Sacramento          5000.0
# 100   Indeed + Glassdoor           Austin          1300.0
# ...                  ...              ...             ...
# 3930             Groupon          Chicago          2800.0
# 3944                Yelp      SF_Bay_Area          1000.0
# 3979               Toast           Boston          1300.0
# 4033            MindBody  San_Luis_Obispo           700.0
# 4181     Flywheel Sports    New_York_City           784.0
#
#       porcentaje_despidos      industria  \
# 8                0.010000         Retail
# 13               0.040000  Manufacturing
# 53               0.294064          Sales
# 98               0.294064       Hardware
# 100              0.294064             HR
# ...                   ...            ...
# 3930             0.440000         Retail
# 3944             0.170000       Consumer
# 3979             0.500000           Food
# 4033             0.350000        Fitness
# 4181             0.980000        Fitness
#
#                                                  fuente     etapa  \
# 8     https://www.cnbc.com/2025/10/28/amazon-layoffs...  Post-IPO
# 13    https://www.bloomberg.com/news/articles/2025-1...  Post-IPO
# 53    https://www.businessinsider.com/marc-benioff-s...  Post-IPO
# 98    https://www.manufacturingdive.com/news/intel-l...  Post-IPO
# 100   https://www.bloomberg.com/news/articles/2025-0...  Acquired
# ...                                                 ...       ...
# 3930  https://layoffs.fyi/2020/04/17/groupon-laid-of...  Post-IPO
# 3944  https://layoffs.fyi/2020/04/14/yelp-laid-off-1...  Post-IPO
# 3979  https://layoffs.fyi/2020/04/10/toast-cuts-1300...  Series F
# 4033  https://www.sanluisobispo.com/news/business/ar...  Post-IPO
# 4181  https://stayfit305.com/solidcore-and-flywheel-...  Acquired
#
#       fondos_recaudados sector_economico fecha_agregado
# 8                8100.0           Retail     10/28/2025
# 13               2100.0    Manufacturing     10/25/2025
# 53                 65.0            Sales       9/2/2025
# 98                 12.0         Hardware      7/17/2025
# 100                 5.0               HR      7/10/2025
# ...                 ...              ...            ...
# 3930             1400.0           Retail      4/13/2020
# 3944               56.0         Consumer       4/9/2020
# 3979              902.0             Food       4/7/2020
# 4033              114.0          Fitness       4/2/2020
# 4181              120.0          Fitness       4/9/2020
#
# [208 rows x 10 columns]

# %%
# Función para detectar outliers usando el método del IQR
def detectar_outliers(df, columna):
    Q1 = df[columna].quantile(0.25)
    Q3 = df[columna].quantile(0.75)
    IQR = Q3 - Q1
    limite_inf = Q1 - 1.5 * IQR
    limite_sup = Q3 + 1.5 * IQR
    df[f'{columna}_outlier'] = (df[columna] < limite_inf) | (df[columna] > limite_sup)
    return df, Q1, Q3, IQR, limite_inf, limite_sup

df_limpio, Q1, Q3, IQR, inf, sup = detectar_outliers(df, 'datos')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 11
#       8     df[f'{columna}_outlier'] = (df[columna] < limite_inf) | (df[columna] > limite_sup)
#       9     return df, Q1, Q3, IQR, limite_inf, limite_sup
# ---> 11 df_limpio, Q1, Q3, IQR, inf, sup = detectar_outliers(df, 'datos')
#
# Cell In[61], line 3, in detectar_outliers(df, columna)
#       2 def detectar_outliers(df, columna):
# ----> 3     Q1 = df[columna].quantile(0.25)
#       4     Q3 = df[columna].quantile(0.75)
#       5     IQR = Q3 - Q1
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'datos'

# %%
dfprueba1 = pd.DataFrame({'datos':[10, 12, 14, 15, 18, 19, 20, 22, 23, 1000]})
dfprueba2 = pd.DataFrame({'datos':[11, 13, 14, 16, 18, 21, 20, 23, 24, 999]})

d12=pd.concat([dfprueba1, dfprueba2], ignore_index=True, axis=1)
print(d12)
# Out:
#       0    1
# 0    10   11
# 1    12   13
# 2    14   14
# 3    15   16
# 4    18   18
# 5    19   21
# 6    20   20
# 7    22   23
# 8    23   24
# 9  1000  999

# %% [markdown]
# ## 8. Visualización básica (conceptual)

# %% [markdown]
# Los siguientes comandos funcionarían si matplotlib estuviera configurado:
# ```
# df['A'].plot()
# ```

# %% [markdown]
# ## 9. Optimización

# %%
#df = pd.DataFrame({'x':np.random.randint(0,100,size=1000)})
##df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       1000 non-null   int32
# dtypes: int32(1)
# memory usage: 4.0 KB

# %%
#df['x'] = df['x'].astype('int32')
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       1000 non-null   int32
# dtypes: int32(1)
# memory usage: 4.0 KB
